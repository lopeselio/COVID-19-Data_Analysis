# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import style
#style.use('ggplot')
# %matplotlib inline

import plotly
import plotly.express as px
import plotly.graph_objects as go

import cufflinks as cf
import plotly.offline as pyo
from plotly.offline import init_notebook_mode,plot,iplot

import folium

# %%
pyo.init_notebook_mode(connected=True)
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
df = pd.read_excel(r"/home/lion/Downloads/COVID-19-Data-Analyisis-master/Covid cases in India.xlsx")

# %%
df
# Out:
#     S. No. Name of State / UT  Total Confirmed cases (Indian National)  \
# 0        1     Andhra Pradesh                                       12
# 1        2       Chhattisgarh                                        6
# 2        3              Delhi                                       38
# 3        4            Gujarat                                       43
# 4        5            Haryana                                       16
# 5        6   Himachal Pradesh                                        4
# 6        7          Karnataka                                       20
# 7        8             Kerala                                      131
# 8        9     Madhya Pradesh                                       23
# 9       10        Maharashtra                                      144
# 10      11             Odisha                                        3
# 11      12         Puducherry                                        1
# 12      13             Punjab                                       29
# 13      14          Rajasthan                                       41
# 14      15         Tamil Nadu                                       32
# 15      16          Telengana                                       34
# 16      17         Chandigarh                                        7
# 17      18  Jammu and Kashmir                                       18
# 18      19             Ladakh                                       13
# 19      20      Uttar Pradesh                                       42
# 20      21        Uttarakhand                                        4
# 21      22        West Bengal                                       11
# 22      23              Bihar                                        7
# 23      24            Mizoram                                        1
# 24      25                Goa                                        6
# 25      26            Manipur                                        1
#
#     Total Confirmed cases ( Foreign National )  Cured  Death
# 0                                            0      1      0
# 1                                            0      0      0
# 2                                            1      6      1
# 3                                            0      0      3
# 4                                           14     11      0
# 5                                            0      0      1
# 6                                            0      3      2
# 7                                            7     11      0
# 8                                            0      0      1
# 9                                            3     15      4
# 10                                           0      0      0
# 11                                           0      0      0
# 12                                           0      0      1
# 13                                           2      3      0
# 14                                           3      1      1
# 15                                          11      1      0
# 16                                           0      0      0
# 17                                           0      1      1
# 18                                           0      0      0
# 19                                           1     11      0
# 20                                           0      0      0
# 21                                           0      0      1
# 22                                           0      0      1
# 23                                           0      0      0
# 24                                           0      0      0
# 25                                           0      0      0

# %%
df.drop(['S. No.'], axis = 1, inplace = True)

# %%
df
# Out:
#    Name of State / UT  Total Confirmed cases (Indian National)  \
# 0      Andhra Pradesh                                       12
# 1        Chhattisgarh                                        6
# 2               Delhi                                       38
# 3             Gujarat                                       43
# 4             Haryana                                       16
# 5    Himachal Pradesh                                        4
# 6           Karnataka                                       20
# 7              Kerala                                      131
# 8      Madhya Pradesh                                       23
# 9         Maharashtra                                      144
# 10             Odisha                                        3
# 11         Puducherry                                        1
# 12             Punjab                                       29
# 13          Rajasthan                                       41
# 14         Tamil Nadu                                       32
# 15          Telengana                                       34
# 16         Chandigarh                                        7
# 17  Jammu and Kashmir                                       18
# 18             Ladakh                                       13
# 19      Uttar Pradesh                                       42
# 20        Uttarakhand                                        4
# 21        West Bengal                                       11
# 22              Bihar                                        7
# 23            Mizoram                                        1
# 24                Goa                                        6
# 25            Manipur                                        1
#
#     Total Confirmed cases ( Foreign National )  Cured  Death
# 0                                            0      1      0
# 1                                            0      0      0
# 2                                            1      6      1
# 3                                            0      0      3
# 4                                           14     11      0
# 5                                            0      0      1
# 6                                            0      3      2
# 7                                            7     11      0
# 8                                            0      0      1
# 9                                            3     15      4
# 10                                           0      0      0
# 11                                           0      0      0
# 12                                           0      0      1
# 13                                           2      3      0
# 14                                           3      1      1
# 15                                          11      1      0
# 16                                           0      0      0
# 17                                           0      1      1
# 18                                           0      0      0
# 19                                           1     11      0
# 20                                           0      0      0
# 21                                           0      0      1
# 22                                           0      0      1
# 23                                           0      0      0
# 24                                           0      0      0
# 25                                           0      0      0

# %%
df['Total Cases']=df['Total Confirmed cases (Indian National)']+df['Total Confirmed cases ( Foreign National )']

# %%
df
# Out:
#    Name of State / UT  Total Confirmed cases (Indian National)  \
# 0      Andhra Pradesh                                       12
# 1        Chhattisgarh                                        6
# 2               Delhi                                       38
# 3             Gujarat                                       43
# 4             Haryana                                       16
# 5    Himachal Pradesh                                        4
# 6           Karnataka                                       20
# 7              Kerala                                      131
# 8      Madhya Pradesh                                       23
# 9         Maharashtra                                      144
# 10             Odisha                                        3
# 11         Puducherry                                        1
# 12             Punjab                                       29
# 13          Rajasthan                                       41
# 14         Tamil Nadu                                       32
# 15          Telengana                                       34
# 16         Chandigarh                                        7
# 17  Jammu and Kashmir                                       18
# 18             Ladakh                                       13
# 19      Uttar Pradesh                                       42
# 20        Uttarakhand                                        4
# 21        West Bengal                                       11
# 22              Bihar                                        7
# 23            Mizoram                                        1
# 24                Goa                                        6
# 25            Manipur                                        1
#
#     Total Confirmed cases ( Foreign National )  Cured  Death  Total Cases
# 0                                            0      1      0           12
# 1                                            0      0      0            6
# 2                                            1      6      1           39
# 3                                            0      0      3           43
# 4                                           14     11      0           30
# 5                                            0      0      1            4
# 6                                            0      3      2           20
# 7                                            7     11      0          138
# 8                                            0      0      1           23
# 9                                            3     15      4          147
# 10                                           0      0      0            3
# 11                                           0      0      0            1
# 12                                           0      0      1           29
# 13                                           2      3      0           43
# 14                                           3      1      1           35
# 15                                          11      1      0           45
# 16                                           0      0      0            7
# 17                                           0      1      1           18
# 18                                           0      0      0           13
# 19                                           1     11      0           43
# 20                                           0      0      0            4
# 21                                           0      0      1           11
# 22                                           0      0      1            7
# 23                                           0      0      0            1
# 24                                           0      0      0            6
# 25                                           0      0      0            1

# %%
Total_cases_overall = df['Total Cases'].sum()
print('The total number of cases in India till date: ',Total_cases_overall)
# Out:
# The total number of cases in India till date:  729

# %%
df['Total Active Cases'] = df['Total Cases'] - df['Cured']- df['Death']

# %%
df
# Out:
#    Name of State / UT  Total Confirmed cases (Indian National)  \
# 0      Andhra Pradesh                                       12
# 1        Chhattisgarh                                        6
# 2               Delhi                                       38
# 3             Gujarat                                       43
# 4             Haryana                                       16
# 5    Himachal Pradesh                                        4
# 6           Karnataka                                       20
# 7              Kerala                                      131
# 8      Madhya Pradesh                                       23
# 9         Maharashtra                                      144
# 10             Odisha                                        3
# 11         Puducherry                                        1
# 12             Punjab                                       29
# 13          Rajasthan                                       41
# 14         Tamil Nadu                                       32
# 15          Telengana                                       34
# 16         Chandigarh                                        7
# 17  Jammu and Kashmir                                       18
# 18             Ladakh                                       13
# 19      Uttar Pradesh                                       42
# 20        Uttarakhand                                        4
# 21        West Bengal                                       11
# 22              Bihar                                        7
# 23            Mizoram                                        1
# 24                Goa                                        6
# 25            Manipur                                        1
#
#     Total Confirmed cases ( Foreign National )  Cured  Death  Total Cases  \
# 0                                            0      1      0           12
# 1                                            0      0      0            6
# 2                                            1      6      1           39
# 3                                            0      0      3           43
# 4                                           14     11      0           30
# 5                                            0      0      1            4
# 6                                            0      3      2           20
# 7                                            7     11      0          138
# 8                                            0      0      1           23
# 9                                            3     15      4          147
# 10                                           0      0      0            3
# 11                                           0      0      0            1
# 12                                           0      0      1           29
# 13                                           2      3      0           43
# 14                                           3      1      1           35
# 15                                          11      1      0           45
# 16                                           0      0      0            7
# 17                                           0      1      1           18
# 18                                           0      0      0           13
# 19                                           1     11      0           43
# 20                                           0      0      0            4
# 21                                           0      0      1           11
# 22                                           0      0      1            7
# 23                                           0      0      0            1
# 24                                           0      0      0            6
# 25                                           0      0      0            1
#
#     Total Active Cases
# 0                   11
# 1                    6
# 2                   32
# 3                   40
# 4                   19
# 5                    3
# 6                   15
# 7                  127
# 8                   22
# 9                  128
# 10                   3
# 11                   1
# 12                  28
# 13                  40
# 14                  33
# 15                  44
# 16                   7
# 17                  16
# 18                  13
# 19                  32
# 20                   4
# 21                  10
# 22                   6
# 23                   1
# 24                   6
# 25                   1

# %%
df.style.background_gradient(cmap='Reds')
# Out:
# <style  type="text/css" >
#     #T_874ba8de_8e03_11ea_9e97_c9f6d989572arow0_col1 {
#             background-color:  #fee8de;
#             color:  #000000;
#         }    #T_874ba8de_8e03_11ea_9e97_c9f6d989572arow0_col2 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_874ba8de_8e03_11ea_9e97_c9f6d989572arow0_col3 {
#             background-color:  #feeae0;
#             color:  #000000;
#         }    #T_874ba8de_8e03_11ea_9e97_c9f6d989572arow0_col4 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_874ba8de_8e03_11ea_9e97_c9f6d989572arow0_col5 {
#             background-color:  #fee8de;
#             color:  #000000;
#         }    #T_874ba8de_8e03_11ea_9e97_c9f6d989572arow0_col6 {
#             background-color:  #fee8dd;
#             color:  #000000;
#         }    #T_874ba8de_8e03_11ea_9e97_c9f6d989572arow1_col1 {
#             background-color:  #fff0e8;
#             color:  #000000;
#         }    #T_874ba8de_8e03_11ea_9e97_c9f6d989572arow1_col2 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_874ba8de_8e03_11ea_9e97_c9f6d989572arow1_col3 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_874ba8de_8e03_11ea_9e97_c9f6d989572arow1_col4 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_874ba8de_8e03_11ea_9e97_c9f6d989572arow1_col5 {
#             background-color:  #fff0e8;
#             color:  #000000;
#         }    #T_874ba8de_8e03_11ea_9e97_c9f6d989572arow1_col6 {
#             background-color:  #ffeee7;
#             color:  #000000;
#         }    #T_874ba8de_8e03_11ea_9e97_c9f6d989572arow2_col1 {
#             background-color:  #fcb89e;
#             color:  #000000;
#         }    #T_874ba8de_8e03_11ea_9e97_c9f6d989572arow2_col2 {
#             background-color:  #fee9df;
#             color:  #000000;
#         }    #T_874ba8de_8e03_11ea_9e97_c9f6d989572arow2_col3 {
#             background-color:  #fc8a6a;
#             color:  #000000;
#         }    #T_874ba8de_8e03_11ea_9e97_c9f6d989572arow2_col4 {
#             background-color:  #fcbba1;
#             color:  #000000;
#         }    #T_874ba8de_8e03_11ea_9e97_c9f6d989572arow2_col5 {
#             background-color:  #fcb89e;
#             color:  #000000;
#         }    #T_874ba8de_8e03_11ea_9e97_c9f6d989572arow2_col6 {
#             background-color:  #fcbda4;
#             color:  #000000;
#         }    #T_874ba8de_8e03_11ea_9e97_c9f6d989572arow3_col1 {
#             background-color:  #fcad90;
#             color:  #000000;
#         }    #T_874ba8de_8e03_11ea_9e97_c9f6d989572arow3_col2 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_874ba8de_8e03_11ea_9e97_c9f6d989572arow3_col3 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_874ba8de_8e03_11ea_9e97_c9f6d989572arow3_col4 {
#             background-color:  #ca181d;
#             color:  #f1f1f1;
#         }    #T_874ba8de_8e03_11ea_9e97_c9f6d989572arow3_col5 {
#             background-color:  #fcaf93;
#             color:  #000000;
#         }    #T_874ba8de_8e03_11ea_9e97_c9f6d989572arow3_col6 {
#             background-color:  #fca98c;
#             color:  #000000;
#         }    #T_874ba8de_8e03_11ea_9e97_c9f6d989572arow4_col1 {
#             background-color:  #fee4d8;
#             color:  #000000;
#         }    #T_874ba8de_8e03_11ea_9e97_c9f6d989572arow4_col2 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_874ba8de_8e03_11ea_9e97_c9f6d989572arow4_col3 {
#             background-color:  #d01d1f;
#             color:  #f1f1f1;
#         }    #T_874ba8de_8e03_11ea_9e97_c9f6d989572arow4_col4 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_874ba8de_8e03_11ea_9e97_c9f6d989572arow4_col5 {
#             background-color:  #fdcbb6;
#             color:  #000000;
#         }    #T_874ba8de_8e03_11ea_9e97_c9f6d989572arow4_col6 {
#             background-color:  #fedbcc;
#             color:  #000000;
#         }    #T_874ba8de_8e03_11ea_9e97_c9f6d989572arow5_col1 {
#             background-color:  #fff2eb;
#             color:  #000000;
#         }    #T_874ba8de_8e03_11ea_9e97_c9f6d989572arow5_col2 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_874ba8de_8e03_11ea_9e97_c9f6d989572arow5_col3 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_874ba8de_8e03_11ea_9e97_c9f6d989572arow5_col4 {
#             background-color:  #fcbba1;
#             color:  #000000;
#         }    #T_874ba8de_8e03_11ea_9e97_c9f6d989572arow5_col5 {
#             background-color:  #fff2eb;
#             color:  #000000;
#         }    #T_874ba8de_8e03_11ea_9e97_c9f6d989572arow5_col6 {
#             background-color:  #fff2ec;
#             color:  #000000;
#         }    #T_874ba8de_8e03_11ea_9e97_c9f6d989572arow6_col1 {
#             background-color:  #fedecf;
#             color:  #000000;
#         }    #T_874ba8de_8e03_11ea_9e97_c9f6d989572arow6_col2 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_874ba8de_8e03_11ea_9e97_c9f6d989572arow6_col3 {
#             background-color:  #fdcab5;
#             color:  #000000;
#         }    #T_874ba8de_8e03_11ea_9e97_c9f6d989572arow6_col4 {
#             background-color:  #fb694a;
#             color:  #000000;
#         }    #T_874ba8de_8e03_11ea_9e97_c9f6d989572arow6_col5 {
#             background-color:  #fedfd0;
#             color:  #000000;
#         }    #T_874ba8de_8e03_11ea_9e97_c9f6d989572arow6_col6 {
#             background-color:  #fee3d6;
#             color:  #000000;
#         }    #T_874ba8de_8e03_11ea_9e97_c9f6d989572arow7_col1 {
#             background-color:  #940b13;
#             color:  #f1f1f1;
#         }    #T_874ba8de_8e03_11ea_9e97_c9f6d989572arow7_col2 {
#             background-color:  #fb694a;
#             color:  #000000;
#         }    #T_874ba8de_8e03_11ea_9e97_c9f6d989572arow7_col3 {
#             background-color:  #d01d1f;
#             color:  #f1f1f1;
#         }    #T_874ba8de_8e03_11ea_9e97_c9f6d989572arow7_col4 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_874ba8de_8e03_11ea_9e97_c9f6d989572arow7_col5 {
#             background-color:  #840711;
#             color:  #f1f1f1;
#         }    #T_874ba8de_8e03_11ea_9e97_c9f6d989572arow7_col6 {
#             background-color:  #6b010e;
#             color:  #f1f1f1;
#         }    #T_874ba8de_8e03_11ea_9e97_c9f6d989572arow8_col1 {
#             background-color:  #fed8c7;
#             color:  #000000;
#         }    #T_874ba8de_8e03_11ea_9e97_c9f6d989572arow8_col2 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_874ba8de_8e03_11ea_9e97_c9f6d989572arow8_col3 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_874ba8de_8e03_11ea_9e97_c9f6d989572arow8_col4 {
#             background-color:  #fcbba1;
#             color:  #000000;
#         }    #T_874ba8de_8e03_11ea_9e97_c9f6d989572arow8_col5 {
#             background-color:  #fed9c9;
#             color:  #000000;
#         }    #T_874ba8de_8e03_11ea_9e97_c9f6d989572arow8_col6 {
#             background-color:  #fdd4c2;
#             color:  #000000;
#         }    #T_874ba8de_8e03_11ea_9e97_c9f6d989572arow9_col1 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_874ba8de_8e03_11ea_9e97_c9f6d989572arow9_col2 {
#             background-color:  #fdc6b0;
#             color:  #000000;
#         }    #T_874ba8de_8e03_11ea_9e97_c9f6d989572arow9_col3 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_874ba8de_8e03_11ea_9e97_c9f6d989572arow9_col4 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_874ba8de_8e03_11ea_9e97_c9f6d989572arow9_col5 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_874ba8de_8e03_11ea_9e97_c9f6d989572arow9_col6 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
